# %%
n = int(input("Nhap vao so nguyen n: "))
print(n*2)
# Out:
# 10

# %%
a, b = map(float, input("Nhap vao chieu dai, chieu rong cua manh dat: ").split())
c = min(a,b)
d = max(a,b)
trong_cay = c*d - 3.14*((c/2)**2)
print(trong_cay)
# Out:
# 19.269399999999997
